# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioRodrig/3d-portfolio/blob/main/Assign_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link: https://colab.research.google.com/drive/1j6DlvTxXjsAuFrxxjdg4cmyXbJU8gEtr?usp=sharing

# %% [markdown]
# # Cidar - Scaling data

# %%
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from random import randint

from google.colab import drive
drive.mount('/content/drive')

def img_plt(images, labels):
    plt.figure(figsize=(15,8))
    for i in range(1, 11):
        plt.subplot(2, 5, i)
        plt.imshow(images[i-1, :, :])
        plt.title('Label: ' + str(labels[i-1]))
    plt.show()

def feat_plot(features, labels, classes):
    for class_i in classes:
        plt.plot(features[labels[:] == classes[class_i], 0],
                 features[labels[:] == classes[class_i], 1],
                 'o', markersize=15)
    # plt.axis([-2.2, 2.2, -2.2, 2.2])
    plt.xlabel('x: feature 1')
    plt.ylabel('y: feature 2')
    plt.legend(['Class ' + str(classes[class_i]) for class_i in classes])
    plt.show()

def acc_fun(labels_actual, labels_pred):
    acc = np.sum(labels_actual == labels_pred) / len(labels_actual) * 100
    return acc

( x_train, y_train), ( x_test, y_test) = cifar10.load_data()
classes = np.arange(10)
print( x_train.shape)

#part A: Use cifar10 function in keras.datasets to load CIFAR-10 dataset. Split it into the training and testing sets.
#Define a validation set by randomly selecting 20% of the training images along with their corresponding labels. This will be the “validation_data”.

#validation which is 20% of training set
num_train_img = x_train.shape[0]
train_ind = np.arange( 0 , num_train_img )
train_ind_s =  np.random.permutation( train_ind ) #change train_ind_s to train_ind_shuffle
x_train = x_train[ train_ind_s ,: ,: ,: ]
y_train = y_train[ train_ind_s , : ]

x_val = x_train[ 0: int(0.2 * num_train_img) ,: ,: ,: ]
y_val = y_train[ 0: int(0.2 * num_train_img) ,: ]

x_train = x_train[ int(0.2 * num_train_img) : ,: ,: ,: ]
y_train = y_train[ int(0.2 * num_train_img) : ,: ]

# print("samples of training images")
# img_plt( x_train[0:10, :, :, : ], y_train[0:10])

validation_data = (x_val, y_val)

#Part B: Scale the pixel values of the images in all the sets to a value between 0 and 1.
#Perform this process by dividing the image values with 255. Note: No need to flatten the images.

#scaling images
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_val = x_val.astype('float32')
x_train = x_train / 255
x_test = x_test / 255
x_val = x_val / 255

#Part C: Convert the label vectors for all the sets to binary class matrices using to_categorical() Keras function.
#convert class vertors to binary class matrices
y_train_c = to_categorical( y_train, len(classes) )
y_test_c = to_categorical( y_test, len(classes) )
y_val_c = to_categorical( y_val, len(classes) )

#Part D: Using Keras library, build a CNN with the following design: 2 convolutional blocks, 1 flattening layer,1 FC layer with 512 nodes, and 1output layer.
#Each convolutional block consists of two back-to-back Conv layers followed by max pooling. The filter size is 3x3x image_depth.
#The number of filters is 32 in the first convolutional block and 64 in the second block. Use the following network architecture as a reference:

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, Activation, MaxPooling2D
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score

def plot_curve(accuracy_train, loss_train, accuracy_val, loss_val):
    epochs = np.arange(loss_train.shape[0])

    plt.subplot(1, 2, 1)
    plt.plot(epochs, accuracy_train, epochs, accuracy_val)
    # plt.axis([-1, 2, -1, 2])
    plt.xlabel('Epoch#')
    plt.ylabel('Accuracy')
    plt.title('Accuracy')
    plt.legend(['Training', 'Validation'])

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss_train, epochs, loss_val)
    plt.xlabel('Epoch#')
    plt.ylabel('Binary crossentropy loss')
    plt.title('Loss')
    plt.legend(['Training', 'Validation'])
    plt.show()

#defined model
from keras.models import Sequential

model_a = Sequential()
model_a.add(Conv2D(filters = 32, kernel_size = (3, 3), padding='same', activation='relu', input_shape = ( 32, 32, 3 )))
model_a.add(Conv2D( 32, (3, 3), padding = 'same' ))
model_a.add(Activation('relu'))
model_a.add(MaxPooling2D(pool_size=( 2, 2)))

model_a.add(Conv2D( filters = 64, kernel_size = (3, 3), padding = 'same', activation='relu') )
model_a.add(Conv2D( 64, (3, 3), padding = 'same' ))
model_a.add(Activation('relu'))
model_a.add(MaxPooling2D(pool_size=( 2, 2)))

model_a.add(Flatten())
model_a.add(Dense(512, activation='relu'))
model_a.add(Dropout(0.5))
model_a.add(Dense(len(classes), activation='softmax'))
model_a.summary()

#Part E: Compile, train, and then evaluate:
#Compile the network. Make sure to select a correct loss function for this classification problem. Use Adam optimizer (Adam, learning rate of 0.001).
#Use ModelCheckpoint to save the best model based on the lowest validation loss.
#Train the network for 50 epochs with a batch size of 32. Remember to assign the validation set to validation_data in the fit function.
#Plot the training and validation loss for all the epochs in one plot.
#Use the evaluate() Keras function to find the training and validation loss and the accuracy. Report the results.

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model_a.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
save_path = '/content/drive/My Drive/Assign4/model_a_cifar.keras'
callback = ModelCheckpoint(save_path, monitor='val_loss', verbose=0, save_best_only=True, save_freq = 'epoch')
history = model_a.fit(x_train, y_train_c, epochs=50, batch_size=32, validation_data=(x_val, y_val_c), callbacks=[callback])

#Plot training & validation curves
plt.figure(figsize=(9, 5))
acc_curve_train = np.array( history.history[ 'accuracy' ])
loss_curve_train = np.array( history.history[ 'loss' ] )
acc_curve_val = np.array( history.history[ 'val_accuracy' ])
loss_curve_val = np.array( history.history[ 'val_loss' ])
plot_curve( acc_curve_train, loss_curve_train, acc_curve_val,   loss_curve_val )

#Loading the best model, saved based on lowest validation loss
model_a = load_model(save_path)

#evaluating the model on training samples
score = model_a.evaluate( x_train, y_train_c )
print( "Total loss on training set: ", score[0] )
print( "Accuracy of training set: ", score[1] )

#evaluating the model on validation samples
score = model_a.evaluate( x_val, y_val_c )
print( "Total loss on validation set: ", score[0] )
print( "Accuracy of validation set: ", score[1] )
# Out:
# (50000, 32, 32, 3)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ...

# %% [markdown]
# # Cidar - Data Augmentation

# %%
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from random import randint

def img_plt(images, labels):
    plt.figure(figsize=(15,8))
    for i in range(1, 11):
        plt.subplot(2, 5, i)
        plt.imshow(images[i-1, :, :])
        plt.title('Label: ' + str(labels[i-1]))
    plt.show()

def feat_plot(features, labels, classes):
    for class_i in classes:
        plt.plot(features[labels[:] == classes[class_i], 0],
                 features[labels[:] == classes[class_i], 1],
                 'o', markersize=15)
    # plt.axis([-2.2, 2.2, -2.2, 2.2])
    plt.xlabel('x: feature 1')
    plt.ylabel('y: feature 2')
    plt.legend(['Class ' + str(classes[class_i]) for class_i in classes])
    plt.show()

def acc_fun(labels_actual, labels_pred):
    acc = np.sum(labels_actual == labels_pred) / len(labels_actual) * 100
    return acc

( x_train, y_train), ( x_test, y_test) = cifar10.load_data()
classes = np.arange(10)
print( x_train.shape)

#validation which is 20% of training set
num_train_img = x_train.shape[0]
train_ind = np.arange( 0 , num_train_img )
train_ind_s =  np.random.permutation( train_ind ) #change train_ind_s to train_ind_shuffle
x_train = x_train[ train_ind_s ,: ,: ,: ]
y_train = y_train[ train_ind_s , : ]

x_val = x_train[ 0: int(0.2 * num_train_img) ,: ,: ,: ]
y_val = y_train[ 0: int(0.2 * num_train_img) ,: ]

x_train = x_train[ int(0.2 * num_train_img) : ,: ,: ,: ]
y_train = y_train[ int(0.2 * num_train_img) : ,: ]

# print("samples of training images")
# img_plt( x_train[0:10, :, :, : ], y_train[0:10])

validation_data = (x_val, y_val)

# #scaling images
# x_train = x_train.astype('float32')
# x_test = x_test.astype('float32')
# x_val = x_val.astype('float32')

#convert class vertors to binary class matrices
y_train_c = to_categorical( y_train, len(classes) )
y_test_c = to_categorical( y_test, len(classes) )
y_val_c = to_categorical( y_val, len(classes) )


import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, Activation, MaxPooling2D
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score
from keras.regularizers import l2

def plot_curve(accuracy_train, loss_train, accuracy_val, loss_val):
    epochs = np.arange(loss_train.shape[0])

    plt.subplot(1, 2, 1)
    plt.plot(epochs, accuracy_train, epochs, accuracy_val)
    # plt.axis([-1, 2, -1, 2])
    plt.xlabel('Epoch#')
    plt.ylabel('Accuracy')
    plt.title('Accuracy')
    plt.legend(['Training', 'Validation'])

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss_train, epochs, loss_val)
    plt.xlabel('Epoch#')
    plt.ylabel('Binary crossentropy loss')
    plt.title('Loss')
    plt.legend(['Training', 'Validation'])
    plt.show()

#defined model
from keras.models import Sequential

model_a = Sequential()
model_a.add(Conv2D(filters = 32, kernel_size = (3, 3), padding='same', activation='relu', input_shape = ( 32, 32, 3 )))
model_a.add(Conv2D( 32, (3, 3), padding = 'same' ))
model_a.add(Activation('relu'))
model_a.add(MaxPooling2D(pool_size=( 2, 2)))

model_a.add(Conv2D( filters = 64, kernel_size = (3, 3), padding = 'same', activation='relu') )
model_a.add(Conv2D( 64, (3, 3), padding = 'same' ))
model_a.add(Activation('relu'))
model_a.add(MaxPooling2D(pool_size=( 2, 2)))

model_a.add(Flatten())
model_a.add(Dense(512, activation='relu'))
model_a.add(Dropout(0.5))
model_a.add(Dense(len(classes), activation='softmax'))
model_a.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model_a.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

#Part F:
#Now define another model with the same architecture in (d) and then:
#Compile the network. Make sure to select a correct loss function for this classification problem. Use Adam optimizer (Adam, learning rate of 0.001).
#Use ModelCheckpoint to save the best model based on the lowest validation loss.
#Create an image data generator in Keras for real-time data augmentation. The augmentation operations are rotation (10 degrees range), width and height shift (0.1 range),
#and horizontal flip.Train the network for 50 epochs with a batch size of 32. Remember to use the image data generator. Assign the validation set to validation_data in the fit function.
#Plot the training and validation loss for all the epochs in one plot.
#Use the evaluate() Keras function to find the training and validation loss and the accuracy. Report the results

#data generator
datagen = ImageDataGenerator(
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True
)
datagen.fit(x_train)

save_path = '/content/drive/My Drive/Assign4/model_a_cifar.keras'
callback = ModelCheckpoint(save_path, monitor='val_loss', verbose=0, save_best_only=True, save_freq = 'epoch')
history = model_a.fit( datagen.flow( x_train, y_train_c, batch_size=32 ), epochs=50, validation_data=( x_val, y_val_c ), callbacks=[callback] )

#Plot training & validation curves
plt.figure(figsize=(9, 5))
acc_curve_train = np.array( history.history[ 'accuracy' ])
loss_curve_train = np.array( history.history[ 'loss' ] )
acc_curve_val = np.array( history.history[ 'val_accuracy' ])
loss_curve_val = np.array( history.history[ 'val_loss' ])
plot_curve( acc_curve_train, loss_curve_train, acc_curve_val,   loss_curve_val )

#Loading the best model, saved based on lowest validation loss
model_a = load_model(save_path)

#evaluating the model on training samples
score = model_a.evaluate( x_train, y_train_c )
print( "Total loss on training set: ", score[0] )
print( "Accuracy of training set: ", score[1] )

#evaluating the model on validation samples
score = model_a.evaluate( x_val, y_val_c )
print( "Total loss on validation set: ", score[0] )
print( "Accuracy of validation set: ", score[1] )
# Out:
# (50000, 32, 32, 3)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ...

# %%
#Part G:
#Onlooking Part E validation loss I noticed overfitting around epoch 7, accuracy for it was around 90.0 and was 29.0 for validation
#loss. Part F differed by having its validation and training line parallel to one another. No visable overfitting was done, but normal oscillation.
#Part B ended up being bast case in terms of allowing data be free of overfitting, given the nature of data augmentation having several thorough examination of data.
#The only cons are computation takes much longer given CNN models slow nature when running and essentially doubling the data doubles the work done.

# %% [markdown]
# # Cifar - Batch Normalization

# %%
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from random import randint

def img_plt(images, labels):
    plt.figure(figsize=(15,8))
    for i in range(1, 11):
        plt.subplot(2, 5, i)
        plt.imshow(images[i-1, :, :])
        plt.title('Label: ' + str(labels[i-1]))
    plt.show()

def feat_plot(features, labels, classes):
    for class_i in classes:
        plt.plot(features[labels[:] == classes[class_i], 0],
                 features[labels[:] == classes[class_i], 1],
                 'o', markersize=15)
    # plt.axis([-2.2, 2.2, -2.2, 2.2])
    plt.xlabel('x: feature 1')
    plt.ylabel('y: feature 2')
    plt.legend(['Class ' + str(classes[class_i]) for class_i in classes])
    plt.show()

def acc_fun(labels_actual, labels_pred):
    acc = np.sum(labels_actual == labels_pred) / len(labels_actual) * 100
    return acc

( x_train, y_train), ( x_test, y_test) = cifar10.load_data()
classes = np.arange(10)
print( x_train.shape)

#validation which is 20% of training set
num_train_img = x_train.shape[0]
train_ind = np.arange( 0 , num_train_img )
train_ind_s =  np.random.permutation( train_ind ) #change train_ind_s to train_ind_shuffle
x_train = x_train[ train_ind_s ,: ,: ,: ]
y_train = y_train[ train_ind_s , : ]

x_val = x_train[ 0: int(0.2 * num_train_img) ,: ,: ,: ]
y_val = y_train[ 0: int(0.2 * num_train_img) ,: ]

x_train = x_train[ int(0.2 * num_train_img) : ,: ,: ,: ]
y_train = y_train[ int(0.2 * num_train_img) : ,: ]

# print("samples of training images")
# img_plt( x_train[0:10, :, :, : ], y_train[0:10])

validation_data = (x_val, y_val)

#scaling images
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_val = x_val.astype('float32')
x_train = x_train / 255
x_test = x_test / 255
x_val = x_val / 255

#convert class vertors to binary class matrices
y_train_c = to_categorical( y_train, len(classes) )
y_test_c = to_categorical( y_test, len(classes) )
y_val_c = to_categorical( y_val, len(classes) )

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, Activation, MaxPooling2D, BatchNormalization
from keras.regularizers import l1
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score

def plot_curve(accuracy_train, loss_train, accuracy_val, loss_val):
    epochs = np.arange(loss_train.shape[0])

    plt.subplot(1, 2, 1)
    plt.plot(epochs, accuracy_train, epochs, accuracy_val)
    # plt.axis([-1, 2, -1, 2])
    plt.xlabel('Epoch#')
    plt.ylabel('Accuracy')
    plt.title('Accuracy')
    plt.legend(['Training', 'Validation'])

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss_train, epochs, loss_val)
    plt.xlabel('Epoch#')
    plt.ylabel('Binary crossentropy loss')
    plt.title('Loss')
    plt.legend(['Training', 'Validation'])
    plt.show()

#defined model
from keras.models import Sequential

model_a = Sequential()
model_a.add(Conv2D(filters = 32, kernel_size = (3, 3), padding='same', activation='relu', input_shape = ( 32, 32, 3 ), use_bias=False))
model_a.add( BatchNormalization() )
model_a.add(Conv2D( 32, (3, 3), padding = 'same', use_bias=False ))
model_a.add( BatchNormalization() )
model_a.add(Activation('relu'))
model_a.add(MaxPooling2D(pool_size=( 2, 2)))

model_a.add(Conv2D( filters = 64, kernel_size = (3, 3), padding = 'same', use_bias=False, activation='relu') )
model_a.add( BatchNormalization() )
model_a.add(Conv2D( 64, (3, 3), padding = 'same', use_bias=False ))
model_a.add( BatchNormalization() )
model_a.add(Activation('relu'))
model_a.add(MaxPooling2D(pool_size=( 2, 2)))

model_a.add( Flatten() )
model_a.add( Dense(512, activation='relu') )
model_a.add( BatchNormalization() )
model_a.add( Activation('relu') )
model_a.add(Dropout(0.5))
model_a.add( Dense(len(classes), activation='softmax') )
model_a.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model_a.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

#Now define another model with the same architecture in (d) and then:
#Compile the network. Make sure to select a correct loss function for this classification problem. Use Adam optimizer (Adam, learning rate of 0.001).
#Use ModelCheckpoint to save the best model based on the lowest validation loss.
#Create an image data generator in Keras for real-time data augmentation. The augmentation operations are rotation (10 degrees range), width and height shift (0.1 range),
#and horizontal flip.Train the network for 50 epochs with a batch size of 32. Remember to use the image data generator. Assign the validation set to validation_data in the fit function.
#Plot the training and validation loss for all the epochs in one plot.
#Use the evaluate() Keras function to find the training and validation loss and the accuracy. Report the results

save_path = '/content/drive/My Drive/Assign4/model_a_cifar.keras'
callback = ModelCheckpoint(save_path, monitor='val_loss', verbose=0 , save_best_only=True, save_freq = 'epoch')
history = model_a.fit(x_train, y_train_c, epochs=50, batch_size=64, validation_data=(x_val, y_val_c), callbacks=[callback])

#Plot training & validation curves
plt.figure(figsize=(9, 5))
acc_curve_train = np.array( history.history[ 'accuracy' ])
loss_curve_train = np.array( history.history[ 'loss' ] )
acc_curve_val = np.array( history.history[ 'val_accuracy' ])
loss_curve_val = np.array( history.history[ 'val_loss' ])
plot_curve( acc_curve_train, loss_curve_train, acc_curve_val,   loss_curve_val )

#Loading the best model, saved based on lowest validation loss
model_a = load_model(save_path)

#evaluating the model on training samples
score = model_a.evaluate( x_train, y_train_c )
print( "Total loss on training set: ", score[0] )
print( "Accuracy of training set: ", score[1] )

#evaluating the model on validation samples
score = model_a.evaluate( x_val, y_val_c )
print( "Total loss on validation set: ", score[0] )
print( "Accuracy of validation set: ", score[1] )
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# (50000, 32, 32, 3)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# ...

# %%
#Part I:
#Training loss thats been shown on part E has overfitting occur around epoch and it floats around 0.29 in the loss.
#Training loss thats been shown on part h has overfitting as well but in epoch 15 is when is really starts to go off
#to the side. The loss is floating at 0.33. Unlike Part F showing amazing results with no overfitting, our batch normalization helps in
#holding a linear state once its gone and overfitted. Its normalization layers help to simplify complexity in each convolutional layer
#speeding up the overall process and allowing the developer to increase learning rate. Batch sizes increased in sizes help faster convergence as a result.
